# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Indumathi**
#
# Senior Analyst

# %% [markdown]
# *I am interested in data science because of my passion to extract hidden useful information from data and help the healthcare workers.*

# %% [markdown]
# ### The following code performs opperation of adding two numbers

# %%
sum = 5+5
print(sum)
# Out:
# 10

# %% [markdown]
# 1. One
# 2. Two
# 3. Three
#
# * Dot List 1
# * Dot List 2
# * Dot List 3
#
# [My notebook link](https://jp-tok.dataplatform.cloud.ibm.com/analytics/notebooks/v2/5ac5fd81-3331-4098-bacc-3e07743bb425/view?access_token=cb8995222e5fdb252ee90d68ebe60907ca6dc146f670fa3066d38ce8466cb859)
#
# ~~OOPS~~
